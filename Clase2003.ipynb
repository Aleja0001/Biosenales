# %%
import matplotlib
import mne

# %%
raw = mne.io.read_raw_eeglab(r'sub-001_task-motion_run-10_eeg.set', preload=True)
print(raw)
print(raw.info)
# Out:
# <RawEEGLAB | sub-001_task-motion_run-10_eeg.set, 64 x 20000 (125.0 s), ~9.8 MiB, data loaded>
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fc5, Fc3, Fc1, Fcz, Fc2, Fc4, Fc6, C5, C3, C1, Cz, C2, C4, C6, ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  dig: 67 items (3 Cardinal, 64 EEG)
#  highpass: 0.0 Hz
#  lowpass: 80.0 Hz
#  meas_date: unspecified
#  nchan: 64
#  projs: []
#  sfreq: 160.0 Hz
# >

# %%
# %matplotlib qt
raw.plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_line_magic('matplotlib', 'qt')
#       2 raw.plot()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:2486, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2484     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2485 with self.builtin_trap:
# -> 2486     result = fn(*args, **kwargs)
#    2488 # The code below prevents the output from being displayed
#    2489 # when using magics with decorator @output_can_be_silenced
#    2490 # when the last Python token in the expression is a ';'.
#    2491 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...
